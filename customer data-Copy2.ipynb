# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt #for plotting the data 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn import metrics
import missingno as msno
import pandas_profiling
# %matplotlib inline

# %%
data=pd.read_csv('customer data.csv')

# %%
data.shape
# Out:
# (168, 188)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Columns: 188 entries, fraudulent to transactions/14/transactionFailed
# dtypes: bool(1), float64(23), object(164)
# memory usage: 245.7+ KB

# %%
data.head()
# Out:
#    fraudulent     customer/customerEmail customer/customerPhone  \
# 0       False     josephhoward@yahoo.com           400-108-5415
# 1        True     evansjeffery@yahoo.com         1-788-091-7546
# 2       False  andersonwilliam@yahoo.com           024.420.0375
# 3       False      rubenjuarez@yahoo.com     670.664.8168x94985
# 4        True           uchen@malone.com         1-981-877-0870
#
#   customer/customerDevice               customer/customerIPAddress  \
# 0    yyeiaxpltf82440jnb3v                             8.129.104.40
# 1    r0jpm7xaeqqa3kr6mzum                          219.173.211.202
# 2    4m7h5ipl1shyavt6vv2r  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
# 3    slovx60t0i558may4ks0  95de:8565:5a66:792c:26e0:6cfb:7d87:11af
# 4    j0pd24k5h8dl2fqu0cz4                           196.89.235.192
#
#                      customer/customerBillingAddress orders/0/orderId  \
# 0          5493 Jones Islands\r\nBrownside, CA 51896           vjbdvd
# ...

# %%
data.columns
# Out:
# Index(['fraudulent', 'customer/customerEmail', 'customer/customerPhone',
#        'customer/customerDevice', 'customer/customerIPAddress',
#        'customer/customerBillingAddress', 'orders/0/orderId',
#        'orders/0/orderAmount', 'orders/0/orderState',
#        'orders/0/orderShippingAddress',
#        ...
#        'transactions/13/transactionId', 'transactions/13/orderId',
#        'transactions/13/paymentMethodId', 'transactions/13/transactionAmount',
#        'transactions/13/transactionFailed', 'transactions/14/transactionId',
#        'transactions/14/orderId', 'transactions/14/paymentMethodId',
#        'transactions/14/transactionAmount',
#        'transactions/14/transactionFailed'],
#       dtype='object', length=188)

# %%
data.describe()
# Out:
#        orders/0/orderAmount  orders/1/orderAmount  \
# count            141.000000            116.000000
# mean              36.028369             33.034483
# std               31.292843             15.862414
# min               10.000000             10.000000
# 25%               19.000000             21.000000
# 50%               33.000000             33.000000
# 75%               45.000000             43.000000
# max              353.000000             75.000000
#
#        transactions/0/transactionAmount  transactions/1/transactionAmount  \
# count                        141.000000                        123.000000
# mean                          36.028369                         33.390244
# std                           31.292843                         16.265539
# min                           10.000000                         10.000000
# 25%                           19.000000                         20.000000
# ...

# %%
data.isna().sum()
# Out:
# fraudulent                                             0
# customer/customerEmail                                 0
# customer/customerPhone                                 0
# customer/customerDevice                                0
# customer/customerIPAddress                             0
# customer/customerBillingAddress                        0
# orders/0/orderId                                      27
# orders/0/orderAmount                                  27
# orders/0/orderState                                   27
# orders/0/orderShippingAddress                         27
# orders/1/orderId                                      52
# orders/1/orderAmount                                  52
# orders/1/orderState                                   52
# orders/1/orderShippingAddress                         52
# paymentMethods/0/paymentMethodId                      12
# paymentMethods/0/paymentMethodRegistrationFailure     12
# ...

# %%
data.drop(['transactions/9/transactionId','transactions/9/orderId','transactions/9/paymentMethodId','transactions/9/transactionAmount','transactions/9/transactionFailed','transactions/10/transactionId','transactions/10/orderId','transactions/10/paymentMethodId','transactions/10/transactionAmount','transactions/10/transactionFailed','transactions/11/transactionId','transactions/11/orderId','transactions/11/paymentMethodId','transactions/11/transactionAmount','transactions/11/transactionFailed','transactions/12/transactionId','transactions/12/orderId','transactions/12/paymentMethodId','transactions/12/transactionAmount','transactions/12/transactionFailed','transactions/13/transactionId','transactions/13/orderId','transactions/13/paymentMethodId','transactions/13/transactionAmount','transactions/13/transactionFailed','transactions/14/transactionId','transactions/14/orderId','transactions/14/paymentMethodId','transactions/14/transactionAmount','transactions/14/transactionFailed'],inplace=True,axis=1)

# %%
data.drop(['customer/customerEmail','customer/customerPhone','customer/customerDevice','customer/customerIPAddress','customer/customerBillingAddress'],inplace=True,axis=1)

# %%
data.columns
# Out:
# Index(['fraudulent', 'orders/0/orderId', 'orders/0/orderAmount',
#        'orders/0/orderState', 'orders/0/orderShippingAddress',
#        'orders/1/orderId', 'orders/1/orderAmount', 'orders/1/orderState',
#        'orders/1/orderShippingAddress', 'paymentMethods/0/paymentMethodId',
#        ...
#        'paymentMethods/14/paymentMethodIssuer', 'orders/7/orderId',
#        'orders/7/orderAmount', 'orders/7/orderState',
#        'orders/7/orderShippingAddress', 'transactions/8/transactionId',
#        'transactions/8/orderId', 'transactions/8/paymentMethodId',
#        'transactions/8/transactionAmount', 'transactions/8/transactionFailed'],
#       dtype='object', length=153)

# %%
data.isna().sum()
# Out:
# fraudulent                                              0
# orders/0/orderId                                       27
# orders/0/orderAmount                                   27
# orders/0/orderState                                    27
# orders/0/orderShippingAddress                          27
# orders/1/orderId                                       52
# orders/1/orderAmount                                   52
# orders/1/orderState                                    52
# orders/1/orderShippingAddress                          52
# paymentMethods/0/paymentMethodId                       12
# paymentMethods/0/paymentMethodRegistrationFailure      12
# paymentMethods/0/paymentMethodType                     12
# paymentMethods/0/paymentMethodProvider                 12
# paymentMethods/0/paymentMethodIssuer                   12
# transactions/0/transactionId                           27
# transactions/0/orderId                                 27
# ...

# %%
data.columns
# Out:
# Index(['fraudulent', 'orders/0/orderId', 'orders/0/orderAmount',
#        'orders/0/orderState', 'orders/0/orderShippingAddress',
#        'orders/1/orderId', 'orders/1/orderAmount', 'orders/1/orderState',
#        'orders/1/orderShippingAddress', 'paymentMethods/0/paymentMethodId',
#        ...
#        'paymentMethods/14/paymentMethodIssuer', 'orders/7/orderId',
#        'orders/7/orderAmount', 'orders/7/orderState',
#        'orders/7/orderShippingAddress', 'transactions/8/transactionId',
#        'transactions/8/orderId', 'transactions/8/paymentMethodId',
#        'transactions/8/transactionAmount', 'transactions/8/transactionFailed'],
#       dtype='object', length=153)

# %%
data.corr()
# Out:
#                                   fraudulent  orders/0/orderAmount  \
# fraudulent                          1.000000              0.275806
# orders/0/orderAmount                0.275806              1.000000
# orders/1/orderAmount                0.341027              0.450724
# transactions/0/transactionAmount    0.275806              1.000000
# transactions/1/transactionAmount    0.333266              0.581739
# orders/2/orderAmount                0.426187              0.369328
# transactions/2/transactionAmount    0.345943              0.433834
# transactions/3/transactionAmount    0.418192              0.413295
# transactions/4/transactionAmount    0.381850              0.381530
# orders/3/orderAmount                0.421084              0.428656
# orders/4/orderAmount                0.218506              0.476333
# orders/5/orderAmount                     NaN              0.171349
# orders/6/orderAmount                     NaN             -0.553568
# ...

# %%
x=['orders/0/orderAmount','orders/1/orderAmount','transactions/0/transactionAmount',
   'transactions/1/transactionAmount','orders/2/orderAmount','transactions/2/transactionAmount',
   'transactions/3/transactionAmount','transactions/4/transactionAmount','orders/3/orderAmount',
   'orders/4/orderAmount','transactions/5/transactionAmount','transactions/6/transactionAmount',
   'transactions/7/transactionAmount','transactions/8/transactionAmoun']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()

# %%
data['transactions/8/transactionAmount'].value_counts()
# Out:
# 12.0    1
# 20.0    1
# 35.0    1
# 47.0    1
# 55.0    1
# 67.0    1
# Name: transactions/8/transactionAmount, dtype: int64

# %%
data['orders/1/orderId'].fillna('1',inplace=True)
data['orders/1/orderAmount'].fillna('6',inplace=True)
data['transactions/0/transactionAmount'].fillna('6',inplace=True)
data['orders/0/orderAmount'].fillna('1',inplace=True)
data['orders/0/orderState'].fillna('fulfilled',inplace=True)
data['orders/0/orderId'].fillna('1',inplace=True)
data['transactions/1/transactionAmount'].fillna('6',inplace=True)
data['orders/2/orderAmount'].fillna('6',inplace=True)
data['transactions/2/transactionAmount'].fillna('5',inplace=True)
data['transactions/3/transactionAmount'].fillna('5',inplace=True)
data['transactions/4/transactionAmount'].fillna('5',inplace=True)
data['orders/3/orderAmount'].fillna('3',inplace=True)
data['orders/4/orderAmount'].fillna('2',inplace=True)
data['transactions/5/transactionAmount'].fillna('3',inplace=True)
data['transactions/6/transactionAmount'].fillna('2',inplace=True)
data['transactions/7/transactionAmount'].fillna('2',inplace=True)
data['transactions/8/transactionAmount'].fillna('1',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()

# %%
feat=['orders/0/orderAmount','orders/1/orderAmount','transactions/0/transactionAmount',
   'transactions/1/transactionAmount','orders/2/orderAmount','transactions/2/transactionAmount',
   'transactions/3/transactionAmount','transactions/4/transactionAmount','orders/3/orderAmount',
   'orders/4/orderAmount','transactions/5/transactionAmount','transactions/6/transactionAmount',
   'transactions/7/transactionAmount','transactions/8/transactionAmount']
X=data[feat]
y = data.fraudulent

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=None)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression() 
logreg.fit(x_train, y_train)
# Out:
# C:\Users\vvgls\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(x_test) 
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.82

# %%
y_pred
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#        False, False,  True, False, False, False, False, False])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.80      1.00      0.89        12
#         True       1.00      0.40      0.57         5
#
#    micro avg       0.82      0.82      0.82        17
#    macro avg       0.90      0.70      0.73        17
# weighted avg       0.86      0.82      0.80        17
